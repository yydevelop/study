# %%
import numpy as np
w = np.array([
    [1,2,3],
    [2,3,4]
])
x = np.array([
    [1],
    [2],
    [9]
])
a = w.dot(x)
a
# Out:
# array([[32],
#        [44]])

# %%
import numpy as np
w = np.array([
    [2,3,4],[5,6,5]
])
x = np.array([
    [1],
    [2],
    [3]
])
b = np.array([
    [2],
    [3]
])
a = w.dot(x)+b
a
# Out:
# array([[22],
#        [35]])

# %%
import numpy as np
def sigmoid(x):
    y=1/(1+np.exp(-x))
    return y
x = 100
sigmoid(x)
# Out:
# 1.0

# %%
def RSS(y,t):
    return 0.5 * (np.sum(y-t))
w=np.array([0.2])
x = np.array([25])
t = np.array([1])
a = w.dot(x)
y= sigmoid(a)
E = RSS(y,t)
E
# Out:
# -0.003346425462142366

# %%
x_train.ndim
# Out:
# 3

# %%
import pandas as pd
data = pd.DataFrame({
    "col1":[1,2,None,np.nan],
    "col2":[1.2,2.3,None,np.nan],
    "col3":['aaa','bbb',None,np.nan],
})
data
# Out:
#    col1  col2  col3
# 0   1.0   1.2   aaa
# 1   2.0   2.3   bbb
# 2   NaN   NaN  None
# 3   NaN   NaN   NaN

# %%
data.isna()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2   True   True   True
# 3   True   True   True

# %%
data.dropna()
# Out:
#    col1  col2 col3
# 0   1.0   1.2  aaa
# 1   2.0   2.3  bbb

# %%
import pandas as pd
s = pd.Series([3,2,3,2,2])
s2 = pd.Series([2,4,6,8,10])
s
# Out:
# 0    3
# 1    2
# 2    3
# 3    2
# 4    2
# dtype: int64

# %%
s2
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
df = pd.concat([s,s2],axis=1)
df
# Out:
#    0   1
# 0  3   2
# 1  2   4
# 2  3   6
# 3  2   8
# 4  2  10

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split as tts
def f(x):
    return np.sin(2*np.pi*x)
sin_x = np.linspace(0,1,100)
x = np.random.rand(100)[:,np.newaxis]
y = f(x) + np.random.rand(100)[:,np.newaxis] - 0.5
x_train, x_test , y_train ,y_test = tts(x,y)
plt.plot(sin_x,f(sin_x),':')

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split as tts
def f(x):
    return np.sin(2*np.pi*x)
sin_x = np.linspace(0,1,100)
x = np.random.rand(100)[:,np.newaxis]
y = f(x) + np.random.rand(100)[:,np.newaxis] - 0.5
x_train, x_test , y_train ,y_test = tts(x,y)
plt.scatter(x_train,y_train)

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
type(iris)
sns.jointplot('sepal_width','petal_length',data=iris)
# Out:
# C:\python388\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn import datasets
from sklearn import svm
digits = datasets.load_digits()
dataset = digits.data
target = digits.target
train_dataset = dataset[:-10]
train_target = target[:-10]
test_dataset = dataset[-10:]
test_target = target[-10:]
clf = svm.SVC(gamma=0.001,C=100)
clf.fit(train_dataset,train_target)
clf.predict(test_dataset)
# Out:
# array([5, 4, 8, 8, 4, 9, 0, 8, 9, 8])

# %%
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt
iris = datasets.load_iris()
x = iris.data[:,0]
y = iris.data[:,2]
model = linear_model.LinearRegression()
model.fit(x.reshape(-1,1),y)
plt.scatter(x,y)
plt.plot(x,model.predict(x.reshape(-1,1)))
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn import cluster , datasets
iris = datasets.load_iris()
data = iris.data
model = cluster.KMeans(n_clusters=3)
model.fit(data)
labels = model.labels_
ldata = data[labels==0]
plt.scatter(ldata[:,2],ldata[:,3],color='green')
ldata = data[labels==1]
plt.scatter(ldata[:,2],ldata[:,3],color='red')
ldata = data[labels==2]
plt.scatter(ldata[:,2],ldata[:,3],color='blue')

# %%
np.array([
    [1,4,7],
    [2,5,8],
    [3,6,9]
])
# Out:
# array([[1, 4, 7],
#        [2, 5, 8],
#        [3, 6, 9]])

# %%
x = np.array([[1,2],[3,4]])
w = np.array([[8,7],[6,5]])
x.dot(w)
# Out:
# array([[20, 17],
#        [48, 41]])

# %%
y=np.array([
    [4],
    [3]
])
y_pred=np.array([
    [2],
    [1]
])
MSE = np.mean((y-y_pred)**2)
MSE
# Out:
# 4.0

# %%
y=np.array([
    [0.2],
    [0.8]
])
y_pred=np.array([
    [0.1],
    [0.9]
])
MSE = np.mean((y-y_pred)**2)
MSE
# Out:
#   File "<ipython-input-6-fc50f6be62c8>", line 7
#     [0.9.]
#          ^
# SyntaxError: invalid syntax

# %%
sigmoid(0)
# Out:
# 0.5

# %%
import matplotlib.pyplot as plt
x1 = np.linspace(-1, 1)
x2 = sigmoid(-1 + -2 * x1)
plt.plot(x1,x2)
print(sigmoid(-1+-2*2))
# Out:
# 0.0066928509242848554

# %%
sigmoid(-1 + -2 * -2.5)
# Out:
# 0.9820137900379085

# %%
sigmoid(-1 + -2 * 1)
# Out:
# 0.04742587317756678

# %%
t0=0.1
t=0.1
for i in range(1,1001):
    t=t0*(1/i)
print(t)
# Out:
# 0.0001

# %%
w0=0.5
w1=-1
print(sigmoid(w0+(-2*w1)))
print(sigmoid(w0+(-4*w1)))
print(sigmoid(w0+(3*w1)))
print(sigmoid(w0+(4*w1)))
print(sigmoid(w0+(0*w1)))
# Out:
# 0.9241418199787566
# 0.9890130573694068
# 0.07585818002124355
# 0.02931223075135632
# 0.6224593312018546
