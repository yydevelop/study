# %%
# 必要なライブラリのインポート
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')

# 乱数のシードを固定
np.random.seed(0)  

# 2次元ガウス分布で模擬データ100人分を作成
mean = [10, 10]  # 平均値
cov = [[10, 3], [3, 10]]  # 分散共分散行列
x1, y1 = np.random.multivariate_normal(mean, cov, 100).T  # 2次元データ生成
true_false = np.random.rand(100) > 0.9  # 0-1の一様乱数の10%がTrue
label1 = np.where(true_false, 1, 0)  # Advanced indexingでLabelデータ生成

# 次元ガウス分布で模擬データ100人分を作成
mean = [20, 20]  # 平均値
cov = [[8, 4], [4, 8]]  # 分散共分散行列
x2, y2 = np.random.multivariate_normal(mean, cov, 100).T
true_false = np.random.rand(100) > 0.1  # 0-1の一様乱数の90%がTrue  
label2 = np.where(true_false, 1, 0)  # Advanced indexingでLabelデータ生成

# データを描画
X = (np.r_[x1, x2])  # 配列の結合
Y = (np.r_[y1, y2])
label = (np.r_[label1, label2])

# ラベル1の継続会員とラベル0の退会会員をAdvanced indexingで取り出して描画
plt.scatter(X[label == 1], Y[label == 1], marker='^', s=30,
            c='blue', edgecolors='none', label='1:continue')
plt.scatter(X[label == 0], Y[label == 0], marker=',', s=30,
            c='red',  edgecolors='none', label='0:withdraw')
plt.xlabel("Annual number of purchases")
plt.ylabel("Average purchase price")
plt.legend(loc="lower right")  # 凡例の出現位置を制御
plt.show()

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\python388\lib\site-packages (0.18.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\python388\lib\site-packages (from mlxtend) (1.2.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\python388\lib\site-packages (from mlxtend) (1.6.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\python388\lib\site-packages (from mlxtend) (1.0.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\python388\lib\site-packages (from mlxtend) (1.20.2)
# Requirement already satisfied: setuptools in c:\python388\lib\site-packages (from mlxtend) (49.2.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\python388\lib\site-packages (from mlxtend) (3.4.1)
# Requirement already satisfied: scikit-learn>=0.20.3 in c:\python388\lib\site-packages (from mlxtend) (0.24.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python388\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python388\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\python388\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\python388\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (8.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python388\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.0)
# Requirement already satisfied: six in c:\python388\lib\site-packages (from cycler>=0.10->matplotlib>=3.0.0->mlxtend) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\python388\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python388\lib\site-packages (from scikit-learn>=0.20.3->mlxtend) (2.1.0)
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: c:\python388\Include\UNKNOWN
# sysconfig: c:\python388\Include
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: c:\python388\Include\UNKNOWN
# sysconfig: c:\python388\Include
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: You are using pip version 21.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\python388\python.exe -m pip install --upgrade pip' command.

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions

#訓練データとテストデータに分割
Data=(np.c_[X,Y])
X_train,X_test,y_train,y_test=train_test_split(Data,label,random_state=0)

clf=linear_model.LogisticRegression(random_state=0)
clf.fit(X_train,y_train)

plot_decision_regions(X_test,y_test,clf=clf,res=0.01,legend=2)
# Out:
# <AxesSubplot:>

# %%
print(f"Accuracy:{clf.score(X_test,y_test):.2f}")

label_prenew = clf.predict([[20,15]])
print(label_prenew)
# Out:
# Accuracy:0.88
# [1]
